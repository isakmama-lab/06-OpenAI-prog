# %%
import openai
import os
from dotenv import load_dotenv

# .env파일의 환경변수를 불러옵니다.
load_dotenv()

# 환경 변수에서 API KEY를 가져옵니다.
api_key = os.getenv("OPENAI_API_KEY")

print(api_key)
# Out:
# sk-proj-EkK-R1TiYv0nC4phhbfjta2HyM3PxmepOd390UXgWTEJIory10gWeniy9hwDXw-K6mSi_HZyk6T3BlbkFJXZEPYE
