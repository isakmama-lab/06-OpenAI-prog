# %%
import openai
import os
from dotenv import load_dotenv

# .env파일의 환경변수를 불러옵니다.
load_dotenv()

# 환경 변수에서 API KEY를 가져옵니다.
api_key = os.getenv("OPENAI_API_KEY")

print(api_key)
# Out:
# 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

# %%
# API 키 지정하여 클라이언트 선언하기
client = openai.OpenAI(api_key = api_key)

# %% [markdown]
# ### 기본 질문하기

# %%
response = client.chat.completions.create(
  model="gpt-5.6-luna",
  messages=[{"role": "user", "content": "피자 만드는 법을 50자로 알려줘."}])

print(response)
# Out:
# ChatCompletion(id='chatcmpl-EIqKOFss0Zzc6CWz2wiIzmdMuDhN7', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='밀가루에 물·이스트·소금을 섞어 반죽해 소스와 치즈를 올려 220℃에 12분 구우면 완성!', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1788159760, model='gpt-5.6-luna', object='chat.completion', metadata=None, moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=1048, prompt_tokens=17, total_tokens=1065, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=995, rejected_prediction_tokens=0, text_tokens=None), compute_units=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=0, cached_tokens=0, image_tokens=None, text_tokens=None)))

# %%
print(response.choices[0].message.content)
# Out:
# 밀가루에 물·이스트·소금을 섞어 반죽해 소스와 치즈를 올려 220℃에 12분 구우면 완성!

# %%
print(response.usage)
# Out:
# CompletionUsage(completion_tokens=1048, prompt_tokens=17, total_tokens=1065, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=995, rejected_prediction_tokens=0, text_tokens=None), compute_units=None, prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cache_write_tokens=0, cached_tokens=0, image_tokens=None, text_tokens=None))

# %%
response.usage.prompt_tokens
# Out:
# 17

# %%
total_bill_USD = (response.usage.completion_tokens*0.002 +response.usage.prompt_tokens*0.001)/1000
# 26.08.31 기준 환율 1USD = 1370.30 KRW
total_bill_KRW = total_bill_USD*1370.30
print("총 소모 비용 : {} 원".format(total_bill_KRW))
# Out:
# 총 소모 비용 : 2.8954438999999996 원

# %% [markdown]
# #### 역할 부여하기

# %%
response = client.chat.completions.create(
 model="gpt-4o-mini",
 messages=[
    {"role": "system", "content": "너는 친절하게 답변해주는 비서야."},
    {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
 ]
)
print(response.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 로스앤젤레스 다저스가 텍사스 레인저스 스타디움에서 열린 시리즈에서 탬파베이 레이스를 이기고 우승했습니다. 다저스는 32년 만에 월드시리즈 타이틀을 차지한 것이었습니다.

# %%
response = client.chat.completions.create(
  model="gpt-5.6-luna",
  messages=[
    {"role": "system", "content": "너는 친절하게 답변해주는 비서야."},
    {"role": "user", "content": "2026년 미국과 이란 전쟁이 발생한 날은?"}
  ]
)
print(response.choices[0].message.content)
# Out:
# 2026년 미국과 이란 사이에 **전쟁이 발발했다는 공식적으로 확인된 사실은 없습니다.** 따라서 전쟁이 발생한 특정 날짜도 없습니다. 특정 군사 충돌이나 보도 내용을 말씀하신 것이라면 사건명이나 출처를 알려주세요.

# %%
response = client.chat.completions.create(
 model="gpt-4o-mini",
 messages=[
 {"role": "system", "content": "You must only answer users' questions in English.\
   This must be honored. You must only answer in English."},
 {"role": "user", "content": "2022년 월드컵에서는 누가 우승했어?"}
 ]
)
print(response.choices[0].message.content)
# Out:
# Argentina won the 2022 FIFA World Cup. They defeated France in the final match.

# %% [markdown]
# #### 이어서 질문하기

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "너는 친절하게 답변해주는 비서야."},
    {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"},
    {"role": "assistant", "content": "바로 예상을 뚫고 4강 진출 신화를 일으킨 한국입니다."},
    {"role": "user", "content": "그 나라가 화제가 되었던 이유를 자세히 설명해줘."}
  ]
)
print(response.choices[0].message.content)
# Out:
# 2002년 FIFA 월드컵에서 한국이 화제를 모은 이유는 여러 가지가 있습니다.
#
# 1. **역사적인 성과**: 한국은 2002년 월드컵에서 아시아 국가로는 최초로 4강에 진출했습니다. 이는 월드컵 역사상 매우 이례적인 사건으로 많은 사람들의 주목을 받았습니다.
#
# 2. **경기 내용**: 한국은 조별 리그에서 폴란드, 미국, 포르투갈을 상대로 승리하며 16강에 진출했습니다. 특히 포르투갈과의 경기에서는 1-0으로 이겼던 경기가 큰 이변으로 여겨졌습니다. 이어서 16강에서 이탈리아를 상대로 연장전 끝에 승리를 거두고, 4강에서는 독일에게 패배했지만 그 과정에서의 열정적인 경기력은 많은 이들의 기억에 남았습니다.
#
# 3. **홈 어드밴티지**: 2002년 월드컵은 한국과 일본 공동 개최였고, 한국에서 열리는 경기가 많은 영향력을 미쳤습니다. 홈에서 경기를 치르며 관중의 열렬한 응원이 큰 힘이 되었습니다.
#
# 4. **선수들의 활약**: 박지성, 홍명보, 설기현 등 여러 선수들이 뛰어난 활약을 보여주었고, 특히 안정환의 결승골과 같은 플레이가 많은 이들에게 인상 깊게 남았습니다.
#
# 5. **국민적 열기**: 한국 전역에서 월드컵 응원을 위한 대규모 집회와 행사들이 열렸고, 이는 국민적 단합과 사기를 높였습니다. 거리마다 태극기가 나부끼고 응원가가 불려지는 등 한국 사회에 큰 활력을 불어넣었습니다.
#
# 이러한 요소들이 결합되어 한국은 2002년 월드컵에서 큰 화제가 되었고, 그 결과는 지금까지도 많은 이들에게 기억되고 있습니다.

# %% [markdown]
# #### JSON 형태로 답변 받기

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini",
  response_format={"type":"json_object"},
  messages=[
    {"role": "system", "content": "너는 친절하게 답변해주는 비서야. 질문에 대해 JSON형식으로 답해줘."},
    {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"},
  ]
)
print(response.choices[0].message.content)
# Out:
# {
#   "대회": "2002년 월드컵",
#   "주최국": ["한국", "일본"],
#   "가장_화제된_나라": "한국",
#   "사유": "한국은 2002년 월드컵에서 4위라는 성적을 기록하며, 아시아 국가로는 최초로 월드컵 4강에 진출, 많은 주목을 받았다."
# }
