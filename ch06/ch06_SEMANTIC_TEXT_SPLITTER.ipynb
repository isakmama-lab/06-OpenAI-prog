# %%
# !pip install langchain_openai langchain_experimental
# Out:
# Requirement already satisfied: langchain_openai in C:\06 OpenAI-prog\.venv\Lib\site-packages (1.6.0)
# Requirement already satisfied: langchain_experimental in C:\06 OpenAI-prog\.venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: certifi>=2024.6.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain_openai) (2026.7.22)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain_openai) (1.6.1)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain_openai) (3.6.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain_openai) (0.14.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (2.13.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.17.0)
# Requirement already satisfied: anyio in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain_openai) (4.14.2)
# Requirement already satisfied: httpcore==1.* in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain_openai) (1.0.9)
# Requirement already satisfied: idna in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain_openai) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain_openai) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.10.4)
# Requirement already satisfied: jiter<1,>=0.16.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain_openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.0->langchain_openai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.0->langchain_openai) (0.4.4)
# Requirement already satisfied: regex in C:\06 OpenAI-prog\.venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.9.3)
# Requirement already satisfied: langchain-community<1.0.0,>=0.4.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain_experimental) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain_experimental) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain_experimental) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain_experimental) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain_experimental) (2.5.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain_experimental) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community<1.0.0,>=0.4.2->langchain_experimental) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain_openai) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community<1.0.0,>=0.4.2->langchain_experimental) (3.5.5)

# %%
import os
import urllib.request
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_experimental.text_splitter import SemanticChunker


import os
from dotenv import load_dotenv

# .env파일의 환경변수를 불러옵니다.
load_dotenv()

# 환경 변수에서 API KEY를 가져옵니다.
api_key = os.getenv("OPENAI_API_KEY")

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/chatgpt-kr/openai-api-tutorial/main/ch06/test.txt", filename="test.txt")

with open("test.txt", encoding="utf-8") as f:
    file = f.read()
print('텍스트의 길이:', len(file))
# Out:
# 텍스트의 길이: 7460

# %%
text_splitter = SemanticChunker(OpenAIEmbeddings())
texts = text_splitter.create_documents([file])
print('분할된 청크의 수:', len(texts))
# Out:
# 분할된 청크의 수: 10

# %%
import textwrap
content = texts[4].page_content
print(textwrap.fill(content, width=70))
len(texts[4].page_content)
# Out:
# 그의 논문들이 주요 학회에서 발표되면서 학계에서도 그의 이름이 알려지기 시작했다. 2015년, 마침내 그는 세계적인 IT
# 기업인 구글에 합류하게 되었다. 이는 박민호에게 큰 전환점이 되었다. 구글에서 그는 다양한 인공지능 프로젝트에 참여하며,
# 글로벌 무대에서 자신의 역량을 발휘했다. 전 세계에서 모인 우수한 인재들과 협업하며 그는 더욱 성장할 수 있었다. 구글에서
# 박민호는 주로 자율주행 자동차 프로젝트와 관련된 인공지능 기술 개발에 깊이 관여했다. 그의 연구는 자율주행 시스템의 안전성과
# 효율성을 크게 향상시켰다. 이 업적으로 그는 회사 내에서 '올해의 혁신가' 상을 수상하기도 했다. 그러나 성공 속에서도
# 박민호는 고향과 가족에 대한 그리움을 잊지 않았다. 매년 휴가 때마다 한국을 방문해 어머니를 뵙고, 고향 마을을 찾아갔다.
# 그는 자신의 성공이 단지 개인의 노력만으로 이루어진 것이 아니라, 많은 이들의 지지와 격려 덕분이라고 생각했다. 한국에서의
# 재도전 2020년, 박민호는 큰 결심을 하고 한국으로 돌아왔다. 그는 자신의 경험과 지식을 한국의 젊은 인재들과 나누고 싶다는
# 생각을 하게 되었다. 또한, 한국의 IT 산업이 글로벌 시장에서 더 큰 경쟁력을 갖출 수 있도록 돕고 싶었다. 귀국 후 그는
# 자신의 IT 스타트업을 설립했다. 회사의 이름은 '네오텍(NeoTech)'으로, '새로운 기술로 더 나은 미래를 만든다'는
# 의미를 담았다. 네오텍은 인공지능과 빅데이터 기술을 활용한 혁신적인 솔루션을 개발하는 것을 목표로 삼았다. 처음에는 많은
# 어려움이 있었다.
# 767

# %%
content = texts[5].page_content
print(textwrap.fill(content, width=70))
len(texts[5].page_content)
# Out:
# 미국에서의 경력이 화려했음에도 불구하고, 한국 시장에서는 새로운 도전자에 불과했다. 투자를 받는 것도, 우수한 인재를 영입하는
# 것도 쉽지 않았다. 그러나 박민호는 포기하지 않았다. 그는 자신의 비전을 끊임없이 설명하고, 열정적으로 사업을 추진했다. 점차
# 네오텍은 성장하기 시작했다. 박민호의 글로벌 경험과 첨단 기술력이 결합된 네오텍의 솔루션들이 시장에서 주목받기 시작한 것이다.
# 특히 그가 개발한 AI 기반 교육 플랫폼은 코로나19 팬데믹 시기에 온라인 학습의 질을 크게 향상시켜 많은 학생들과
# 교사들로부터 호평을 받았다. 2년이 지난 후, 네오텍은 한국의 대표적인 AI 기업으로 자리잡았다. 회사는 빠르게 성장하며
# 국내외에서 주목받는 기업이 되었다. 박민호는 자신의 경험과 지식을 바탕으로 혁신적인 기술을 개발하고, 이를 통해 사회에
# 기여하고자 했다. 박민호는 "한국에서 새로 시작하면서 모든 것을 처음부터 다시 배워야 했지만, 서울대에서 배운 학습 방법과
# 연구 경험이 큰 도움이 되었다"고 말했다. 그는 한국과 미국에서 각각 IT 분야에서 성공한 유일한 사람으로, 양국의 기술을
# 통합하여 새로운 혁신을 이루고자 하는 목표를 가지고 있었다. 네오텍은 단순히 이윤을 추구하는 기업이 아니었다. 박민호는 회사의
# 핵심 가치 중 하나로 '사회적 책임'을 강조했다. 그는 회사의 수익 중 일부를 항상 사회공헌 활동에 사용했다. 특히 그의
# 고향인 어촌 마을의 교육 환경 개선을 위해 많은 노력을 기울였다. 미래를 향한 도전과 비전 박민호는 IT 기술을 통해 사회에
# 기여하는 것을 목표로 삼고 있다. 그는 자신의 스타트업을 통해 다양한 사회 문제를 해결하고, 더 나은 세상을 만들기 위해
# 노력하고 있다. 그는 특히 교육과 의료 분야에서 인공지능 기술을 활용한 혁신적인 솔루션을 개발하는 데 주력하고 있다. 교육
# 분야에서는 개인화된 학습 시스템을 개발하여 학생들의 학습 효과를 극대화하고 있다. 이 시스템은 각 학생의 학습 패턴과 성향을
# 분석하여 최적화된 학습 계획을 제시한다. 의료 분야에서는 AI를 활용한 진단 보조 시스템을 개발하여 의사들의 정확한 진단을
# 돕고 있다. 박민호는 "기술은 사람들을 더 나은 삶으로 인도하는 도구"라고 말한다.
# 1082

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(texts[6].page_content)
len(texts[6].page_content)
# Out:
# 그는 자신의 기술을 통해 사람들의 삶을 개선하고, 더 많은 이들에게 기회를 제공하는 것을 중요하게 생각한다. 특히 그는 기술의 혜택이 사회의 모든 계층에 골고루 돌아가야 한다고 믿는다. 이를 위해 박민호는 네오텍의 기술을 활용하여 소외계층을 위한 다양한 프로그램을 운영하고 있다. 예를 들어, 저소득층 학생들을 위한 무료 온라인 교육 프로그램을 제공하고 있으며, 농어촌 지역의 의료 서비스 개선을 위한 원격 진료 시스템을 개발하고 있다. 박민호는 지속적인 학습과 연구를 통해 끊임없이 발전하며, 자신의 꿈을 향해 나아가고 있다. 그는 매주 금요일 저녁을 '학습의 시간'으로 정해 새로운 기술 트렌드를 공부하고, 다양한 분야의 전문가들과 대화를 나누며 시야를 넓히고 있다. 또한 그는 후배 양성에도 큰 관심을 기울이고 있다. 네오텍은 매년 우수한 인재들을 선발하여 인턴십 프로그램을 운영하고 있으며, 박민호는 직접 멘토링 세션을 진행하며 젊은 인재들을 육성하고 있다. 그의 이야기는 어려움을 극복하고 새로운 삶을 개척한 IT 전문가의 성공 사례로 많은 이들에게 영감을 주고 있다. 작은 어촌마을에서 태어나 세계적인 IT 전문가가 되기까지의 여정은 결코 쉽지 않았지만, 그의 끈기와 열정, 그리고 꿈을 향한 도전 정신이 있었기에 가능했다. 박민호는 한국과 미국에서의 경험을 바탕으로 글로벌 무대에서 활동하며, 더 큰 비전을 가지고 앞으로 나아가고 있다. 그는 앞으로도 기술 혁신을 통해 세상을 더 나은 곳으로 만들고자 하는 그의 꿈을 계속해서 추구할 것이다. 그의 여정은 아직 끝나지 않았다. 박민호는 이제 새로운 도전을 준비하고 있다. 그는 인공지능 기술을 활용하여 기후 변화 문제에 대응하는 솔루션을 개발하고자 한다. 이를 통해 그는 전 세계적인 문제 해결에 기여하고, 동시에 한국의 기술력을 세계에 알리고자 한다. 박민호의 이야기는 우리에게 꿈을 향한 열정과 끈기, 그리고 사회에 대한 책임감의 중요성을 일깨워준다. 그의 삶은 기술이 단순히 이윤을 창출하는 도구가 아니라, 세상을 더 나은 곳으로 만들 수 있는 강력한 힘이 될 수 있음을 보여준다. 앞으로도 그는 새로운 도전과 성공을 이뤄낼 것이며, 그의 여정은 많은 이들에게 희망과 용기를 줄 것이다.
# 1094

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(),
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=95,
)
texts = text_splitter.create_documents([file])
print('분할된 청크의 수:', len(texts))
# Out:
# 분할된 청크의 수: 10

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(),
    breakpoint_threshold_type="standard_deviation",
    breakpoint_threshold_amount=3,
)
texts = text_splitter.create_documents([file])
print('분할된 청크의 수:', len(texts))
# Out:
# 분할된 청크의 수: 3

# %%
text_splitter = SemanticChunker(
    OpenAIEmbeddings(),
    breakpoint_threshold_type="interquartile",
    breakpoint_threshold_amount=1.5
)
texts = text_splitter.create_documents([file])
print('분할된 청크의 수:', len(texts))
# Out:
# 분할된 청크의 수: 7
