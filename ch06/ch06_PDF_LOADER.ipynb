# %%
# !pip install langchain langchain-community pypdf pymupdf pdfplumber
# Out:
# Requirement already satisfied: langchain in C:\06 OpenAI-prog\.venv\Lib\site-packages (1.3.18)
# Requirement already satisfied: langchain-community in C:\06 OpenAI-prog\.venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: pypdf in C:\06 OpenAI-prog\.venv\Lib\site-packages (6.16.2)
# Requirement already satisfied: pymupdf in C:\06 OpenAI-prog\.venv\Lib\site-packages (1.28.2)
# Requirement already satisfied: pdfplumber in C:\06 OpenAI-prog\.venv\Lib\site-packages (0.11.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain) (1.6.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community) (2.5.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: pdfminer.six==20260107 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pdfplumber) (20260107)
# Requirement already satisfied: Pillow>=12.2.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pdfplumber) (12.3.0)
# Requirement already satisfied: pypdfium2>=5.9.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pdfplumber) (5.13.0)
# Requirement already satisfied: cryptography>=36.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from pdfminer.six==20260107->pdfplumber) (50.0.1)
# Requirement already satisfied: cffi>=2.0.0 in C:\06 OpenAI-prog\.venv\Lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber) (2.1.1)
# Requirement already satisfied: pycparser in C:\06 OpenAI-prog\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber) (3.0)

# %%
# import urllib.request
# from langchain.document_loaders import PyPDFLoader
# from langchain_community.document_loaders import PyMuPDFLoader
# from langchain.document_loaders import PDFPlumberLoader

import urllib.request
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import PDFPlumberLoader
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13692\3014169807.py:7: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
urllib.request.urlretrieve("https://github.com/chatgpt-kr/openai-api-tutorial/raw/main/ch06/2023_%EB%B6%81%ED%95%9C%EC%9D%B8%EA%B6%8C%EB%B3%B4%EA%B3%A0%EC%84%9C.pdf", filename="2023_북한인권보고서.pdf")
# Out:
# ('2023_북한인권보고서.pdf', <http.client.HTTPMessage at 0x203b78acfc0>)

# %%
# %%time
loader = PyPDFLoader('2023_북한인권보고서.pdf')
pages = loader.load_and_split()
print('청크의 수:', len(pages))
# Out:
# 청크의 수: 445
# CPU times: total: 11.7 s
# Wall time: 11.9 s

# %%
pages[3]
# Out:
# Document(metadata={'producer': 'Adobe PDF Library 10.0.1', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2023-07-31T13:50:27+09:00', 'moddate': '2023-07-31T13:57:54+09:00', 'trapped': '/False', 'source': '2023_북한인권보고서.pdf', 'total_pages': 448, 'page': 5, 'page_label': '6'}, page_content='2023 북한인권보고서\n04\n올해로 유엔의 북한인권조사위원회 출범 10년, 북한인권결의 채\n택 20년이 됩니다. 그동안 우리는 물론 국제사회가 북한인권을 증진\n하기 위해 노력해 왔지만, 휴전선 이북의 북녘 땅은 여전히 최악의 \n인권 사각지대로 남아 있습니다. 우리와 피를 나눈 북한 동포들이 \n최소한의 인간적인 삶을 누릴 수 있도록 책임감을 갖고 보다 실효적\n인 노력을 펼쳐가야만 합니다. \n2016년 제정된 북한인권법에 기반하여 설립된 북한인권기록센\n터는 2017년부터 북한이탈주민을 대상으로 북한의 전반적인 인권\n실태를 심층적으로 조사하였습니다. 또한 파악된 북한의 인권침해 \n사례들을 ‘세계인권선언’과 ‘국제인권조약’의 기준에 따라 분류하였\n습니다. 이번에 발간되는 「북한인권보고서」는 북한의 인권 상황을 \n시민적·정치적 권리, 경제적·사회적·문화적 권리 등 다양한 측면에\n서 입체적으로 조명하였습니다. 아울러, 여성·아동·장애인 등 취약\n계층, 정치범수용소 및 국군포로·납북자·이산가족 등 특수 인권문\n발간사')

# %%
# %%time
loader = PyMuPDFLoader('2023_북한인권보고서.pdf')
pages = loader.load_and_split()
print('청크의 수:', len(pages))
# Out:
# 청크의 수: 445
# CPU times: total: 1.28 s
# Wall time: 1.58 s

# %%
pages[3]
# Out:
# Document(metadata={'producer': 'Adobe PDF Library 10.0.1', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2023-07-31T13:50:27+09:00', 'source': '2023_북한인권보고서.pdf', 'file_path': '2023_북한인권보고서.pdf', 'total_pages': 448, 'format': 'PDF 1.6', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-07-31T13:57:54+09:00', 'trapped': '', 'modDate': "D:20230731135754+09'00'", 'creationDate': "D:20230731135027+09'00'", 'page': 5}, page_content='2023 북한인권보고서\n04\n올해로 유엔의 북한인권조사위원회 출범 10년, 북한인권결의 채\n택 20년이 됩니다. 그동안 우리는 물론 국제사회가 북한인권을 증진\n하기 위해 노력해 왔지만, 휴전선 이북의 북녘 땅은 여전히 최악의 \n인권 사각지대로 남아 있습니다. 우리와 피를 나눈 북한 동포들이 \n최소한의 인간적인 삶을 누릴 수 있도록 책임감을 갖고 보다 실효적\n인 노력을 펼쳐가야만 합니다. \n2016년 제정된 북한인권법에 기반하여 설립된 북한인권기록센\n터는 2017년부터 북한이탈주민을 대상으로 북한의 전반적인 인권\n실태를 심층적으로 조사하였습니다. 또한 파악된 북한의 인권침해 \n사례들을 ‘세계인권선언’과 ‘국제인권조약’의 기준에 따라 분류하였\n습니다. 이번에 발간되는 「북한인권보고서」는 북한의 인권 상황을 \n시민적·정치적 권리, 경제적·사회적·문화적 권리 등 다양한 측면에\n서 입체적으로 조명하였습니다. 아울러, 여성·아동·장애인 등 취약\n계층, 정치범수용소 및 국군포로·납북자·이산가족 등 특수 인권문\n발간사')

# %%
# %%time
loader = PDFPlumberLoader('2023_북한인권보고서.pdf')
pages = loader.load_and_split()
print('청크의 수:', len(pages))
# Out:
# 청크의 수: 445
# CPU times: total: 18.7 s
# Wall time: 19.2 s
